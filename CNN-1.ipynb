# %%
# import library
import numpy as np
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
#normalisasi
# x_train = x_train.reshape(50000, 3072)
# x_test = x_test.reshape(10000, 3072)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
x_train.shape[:]
# Out:
# (50000, 3072)

# %%
#one hot encoding
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
y_test.shape[1]
# Out:
# 10

# %%
#create model

model = tf.keras.Sequential()

#tambah layer
model.add(tf.keras.layers.Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.BatchNormalization())

#flatten
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.2))

#another layaer
# model.add(tf.keras.layers.Conv2D(256, (3,3),kernel_constraint=tf.keras.constraints.MaxNorm(3), activation='relu'))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Conv2D(128, (3,3),kernel_constraint=tf.keras.constraints.MaxNorm(3), activation='relu'))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.BatchNormalization())

#output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

#compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_28 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 16, 16, 64)        256
# ...

# %%
h = model.fit(x_train, y_train, batch_size=64, epochs=25, validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 23s 468us/sample - loss: 1.7980 - acc: 0.4569 - val_loss: 1.2552 - val_acc: 0.5851
# Epoch 2/25
# 50000/50000 [==============================] - 22s 444us/sample - loss: 1.1743 - acc: 0.6086 - val_loss: 0.9549 - val_acc: 0.6735
# Epoch 3/25
# 50000/50000 [==============================] - 22s 444us/sample - loss: 0.9257 - acc: 0.6813 - val_loss: 0.8084 - val_acc: 0.7146
# Epoch 4/25
# 50000/50000 [==============================] - 22s 443us/sample - loss: 0.8030 - acc: 0.7203 - val_loss: 0.7390 - val_acc: 0.7464
# Epoch 5/25
# 50000/50000 [==============================] - 22s 446us/sample - loss: 0.7330 - acc: 0.7432 - val_loss: 0.6910 - val_acc: 0.7637
# Epoch 6/25
# 50000/50000 [==============================] - 23s 450us/sample - loss: 0.6799 - acc: 0.7615 - val_loss: 0.7189 - val_acc: 0.7518
# Epoch 7/25
# ...

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

# %%
print(accuracy)
# Out:
# 0.8159

# %%
#create model

model2 = tf.keras.Sequential()

#tambah layer
model2.add(tf.keras.layers.Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model2.add(tf.keras.layers.Dropout(0.2))
model2.add(tf.keras.layers.BatchNormalization())
model2.add(tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model2.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model2.add(tf.keras.layers.Dropout(0.2))
model2.add(tf.keras.layers.BatchNormalization())
model2.add(tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model2.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model2.add(tf.keras.layers.Dropout(0.2))
model2.add(tf.keras.layers.BatchNormalization())
model2.add(tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model2.add(tf.keras.layers.Dropout(0.2))
model2.add(tf.keras.layers.BatchNormalization())

#flatten
model2.add(tf.keras.layers.Flatten())
model2.add(tf.keras.layers.Dropout(0.2))

#another layaer
# model.add(tf.keras.layers.Conv2D(256, (3,3),kernel_constraint=tf.keras.constraints.MaxNorm(3), activation='relu'))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Conv2D(128, (3,3),kernel_constraint=tf.keras.constraints.MaxNorm(3), activation='relu'))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.BatchNormalization())

#output layer
model2.add(tf.keras.layers.Dense(10, activation='softmax'))

#compile model
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
i = model2.fit(x_train, y_train, batch_size=64, epochs=25, validation_data=(x_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 24s 472us/sample - loss: 3.0736 - acc: 0.4464 - val_loss: 2.1263 - val_acc: 0.5176
# Epoch 2/25
# 50000/50000 [==============================] - 22s 448us/sample - loss: 1.6815 - acc: 0.6098 - val_loss: 1.3561 - val_acc: 0.6559
# Epoch 3/25
# 50000/50000 [==============================] - 22s 448us/sample - loss: 1.3208 - acc: 0.6653 - val_loss: 1.3422 - val_acc: 0.6601
# Epoch 4/25
# 50000/50000 [==============================] - 22s 446us/sample - loss: 1.1954 - acc: 0.6986 - val_loss: 1.1967 - val_acc: 0.7022
# Epoch 5/25
# 50000/50000 [==============================] - 22s 443us/sample - loss: 1.1553 - acc: 0.7109 - val_loss: 1.2179 - val_acc: 0.6899
# Epoch 6/25
# 50000/50000 [==============================] - 22s 446us/sample - loss: 1.1340 - acc: 0.7221 - val_loss: 1.2562 - val_acc: 0.6740
# Epoch 7/25
# ...

# %%
callbacks = [tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=2),
             tf.keras.callbacks.ModelCheckpoint(filepath="best_model.h5", monitor="val_loss", save_best_only=True)]

# %%
#create model

model3 = tf.keras.Sequential()

#tambah layer
model3.add(tf.keras.layers.Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'))
model3.add(tf.keras.layers.Dropout(0.2))
model3.add(tf.keras.layers.BatchNormalization())
model3.add(tf.keras.layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model3.add(tf.keras.layers.Dropout(0.2))
model3.add(tf.keras.layers.BatchNormalization())
model3.add(tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model3.add(tf.keras.layers.Dropout(0.2))
model3.add(tf.keras.layers.BatchNormalization())
model3.add(tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'))
model3.add(tf.keras.layers.Dropout(0.2))
model3.add(tf.keras.layers.BatchNormalization())

#flatten
model3.add(tf.keras.layers.Flatten())
model3.add(tf.keras.layers.Dropout(0.2))

#another layaer
# model.add(tf.keras.layers.Conv2D(256, (3,3),kernel_constraint=tf.keras.constraints.MaxNorm(3), activation='relu'))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Conv2D(128, (3,3),kernel_constraint=tf.keras.constraints.MaxNorm(3), activation='relu'))
# model.add(tf.keras.layers.Dropout(0.2))
# model.add(tf.keras.layers.BatchNormalization())

#output layer
model3.add(tf.keras.layers.Dense(10, activation='softmax'))

#compile model
model3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
j = model3.fit(x_train, y_train, batch_size=64, epochs=25, validation_data=(x_test, y_test), callbacks=callbacks)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 27s 540us/sample - loss: 1.7786 - acc: 0.4601 - val_loss: 1.5402 - val_acc: 0.5096
# Epoch 2/25
# 50000/50000 [==============================] - 23s 452us/sample - loss: 1.1556 - acc: 0.6162 - val_loss: 1.2108 - val_acc: 0.5982
# Epoch 3/25
# 50000/50000 [==============================] - 23s 453us/sample - loss: 0.9125 - acc: 0.6838 - val_loss: 0.8932 - val_acc: 0.6943
# Epoch 4/25
# 50000/50000 [==============================] - 22s 450us/sample - loss: 0.7943 - acc: 0.7227 - val_loss: 0.7935 - val_acc: 0.7262
# Epoch 5/25
# 50000/50000 [==============================] - 23s 452us/sample - loss: 0.7261 - acc: 0.7453 - val_loss: 0.6972 - val_acc: 0.7600
# Epoch 6/25
# 50000/50000 [==============================] - 23s 454us/sample - loss: 0.6731 - acc: 0.7630 - val_loss: 0.7165 - val_acc: 0.7544
# Epoch 7/25
# ...
